# %% [markdown]
# # Omega 20M TPU v5e Pre-training
# This notebook mounts Google Drive, clones the optimized JAX/Flax Llama repository, installs requirements, and starts the Gradio Live Dashboard for training and chat.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/finny-tech/omega-20m-flax.git /content/omega-20m-flax
# %cd /content/omega-20m-flax

# %%
# !pip install -r requirements.txt

# %%
import gradio as gr
import gradio_ui
gradio_ui.demo.launch(share=True, inline=True)
