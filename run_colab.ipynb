# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# !nvidia-smi

# %%
# !git clone https://github.com/finny-tech-labs/melona-core-ai.git
# %cd melona-core-ai
# !pip install -r requirements.txt

# %%
# Launch the Gradio UI directly in Colab. The UI will control Phase 1 (Pre-training) and Phase 2 (SFT).
# !python gradio_ui.py
